# %% [markdown]
# Q7) Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in. The
# scraped data should include Product Name, Price, Image URL and Average Rating.

# %%
#importing  the required librares
from bs4 import BeautifulSoup
import requests

# %%
# Sending the request to the webpage server to get the source code of the page which is to be scraped by using the request library

page=requests.get("https://www.amazon.in/s?k=mobile+phones+under+20000&ref=nb_sb_noss_1")

# %%
# Let's see show the webpage source code downloaded 
page.content
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://images-eu.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41SIz69qHYL.css,31qGOnSAToL.css,013z33uKh2L.css,017DsKjNQJL.css,0131vqwP5UL.css,41EWOOlBJ9L.css,11TIuySqr6L.css,01ElnPiDxWL.css,11bGSgD5pDL.css,01Dm5eKVxwL.css,01IdKcBuAdL.css,01y-XAlI+2L.css,21N4kUH7pxL.css,01oDR3IULNL.css,41-PwE7+H0L.css,21j0IlW7xKL.css,01XPHJk60-L.css,014OeDQisGL.css,21aPhFy+riL.css,11gneA3MtJL.css,21fecG8pUzL.css,01RddH8vm-L.css,01CFUgsA
# ...

# %%
# Now we will parse this source code by using BeautifulSoup and the parser used here is html.parser as the source code is the HTML.
soup=BeautifulSoup(page.content,'html.parser')

# %%
#Lets see how our parsed structure look like and we will use prettify function to present tit in more understandable and readable format
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:feature:aui-assets -->
# ...

# %%
Product_Name =[]
Price= []
Image_URL = []
Image_URL1 = []
Average_Rating = []

# %%
product_name = soup.find_all('span' , class_= 'a-size-medium a-color-base a-text-normal')
product_name[0:4]
# Out:
# [<span class="a-size-medium a-color-base a-text-normal">Redmi 9A (Nature Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage) | 2.3GHz Mediatek Helio G35 Octa core Processor</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Oppo A31 (Fantasy White, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Samsung Galaxy M11 (Black, 4GB RAM, 64GB Storage) with No Cost EMI/Additional Exchange Offers</span>]

# %%
for i in product_name:
    Product_Name.append(i.get_text())
Product_Name[0:5]
# Out:
# ['Redmi 9A (Nature Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage) | 2.3GHz Mediatek Helio G35 Octa core Processor',
#  'Oppo A31 (Fantasy White, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Samsung Galaxy M11 (Black, 4GB RAM, 64GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storage) - 48MP Quad Camera & Full HD+ Display']

# %%
# Getting Mobile Names.
Product_Name = pd.DataFrame(Product_Name)
Product_Name = Product_Name.rename( columns= { 0: 'Name Of Mobile Phone'})
Product_Name[0:5]
# Out:
#                                 Name Of Mobile Phone
# 0  Redmi 9A (Nature Green, 2GB RAM, 32GB Storage)...
# 1  Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage) | 2....
# 2  Oppo A31 (Fantasy White, 6GB RAM, 128GB Storag...
# 3  Samsung Galaxy M11 (Black, 4GB RAM, 64GB Stora...
# 4  Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storag...

# %%
price = soup.find_all('span' , class_= 'a-price-whole')
price[0:5]
# Out:
# [<span class="a-price-whole">6,999</span>,
#  <span class="a-price-whole">8,999</span>,
#  <span class="a-price-whole">12,490</span>,
#  <span class="a-price-whole">10,999</span>,
#  <span class="a-price-whole">11,499</span>]

# %%
for a in price:
    Price.append( a.get_text())
Price[0:5]
# Out:
# ['6,999', '8,999', '12,490', '10,999', '11,499']

# %%
# Getting Price details
Price= pd.DataFrame(Price)
Price=Price.rename(columns ={ 0 : 'Price'})
Price[0:5]
# Out:
#     Price
# 0   6,999
# 1   8,999
# 2  12,490
# 3  10,999
# 4  11,499

# %%
image_url1 = soup.find_all('img' , class_= 's-image')
image_url1[0:5]
# Out:
# [<img alt="Redmi 9A (Nature Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery" class="s-image" data-image-index="1" data-image-latency="s-product-image" data-image-load="" data-image-source-density="1" src="https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UY218_.jpg" srcset="https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UY218_.jpg 1x, https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UY327_QL65_.jpg 1.5x, https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UY436_QL65_.jpg 2x, https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UY545_QL65_.jpg 2.5x, https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UY654_QL65_.jpg 3x"/>,
# ...

# %%
for img in image_url1:
    Image_URL.append(img.get('src'))
Image_URL[0:5]
# Out:
# ['https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71A9Vo1BatL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/61CnyJ-IbML._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/710jkZNub3S._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71X5I1cVfbL._AC_UY218_.jpg']

# %%
# Getting Url Details
Image_URL=pd.DataFrame(Image_URL)
Image_URL=Image_URL.rename(columns = { 0 : 'Image Url'})
Image_URL
# Out:
#                                             Image Url
# 0   https://m.media-amazon.com/images/I/71sxlhYhKW...
# 1   https://m.media-amazon.com/images/I/71A9Vo1Bat...
# 2   https://m.media-amazon.com/images/I/61CnyJ-IbM...
# 3   https://m.media-amazon.com/images/I/710jkZNub3...
# 4   https://m.media-amazon.com/images/I/71X5I1cVfb...
# 5   https://m.media-amazon.com/images/I/716nHhG9SW...
# 6   https://m.media-amazon.com/images/I/71U2SiHgbi...
# 7   https://m.media-amazon.com/images/I/71SSmaLA7x...
# 8   https://m.media-amazon.com/images/I/71sxlhYhKW...
# 9   https://m.media-amazon.com/images/I/71KCwNV6Mu...
# 10  https://m.media-amazon.com/images/I/71QY6JV6Fh...
# 11  https://m.media-amazon.com/images/I/71sxlhYhKW...
# 12  https://m.media-amazon.com/images/I/71sxlhYhKW...
# 13  https://m.media-amazon.com/images/I/710weRkP-n...
# 14  https://m.media-amazon.com/images/I/71sxlhYhKW...
# 15  https://m.media-amazon.com/images/I/71yYaNztZ0...

# %%
rating= soup('span', class_ = 'a-icon-alt')

# %%
for a in rating:
    Average_Rating.append(a.get_text())

# %%
import pandas as pd

# %%
Average_Rating=pd.DataFrame(Average_Rating)
Average_Rating=Average_Rating.iloc[4:20]

# %%
# Getting Rating Data
Average_Rating.index=range(16)
Average_Rating=Average_Rating.rename(columns = { 0 : 'Rating'})
Average_Rating[0:5]
# Out:
#                Rating
# 0  4.3 out of 5 stars
# 1  4.2 out of 5 stars
# 2  4.3 out of 5 stars
# 3  4.1 out of 5 stars
# 4  4.2 out of 5 stars

# %% [markdown]
# Mobile Phone Data

# %%
Mobile =pd.concat([Product_Name ,Price,Image_URL,Average_Rating],axis=1)
Mobile
# Out:
#                                  Name Of Mobile Phone   Price  \
# 0   Redmi 9A (Nature Green, 2GB RAM, 32GB Storage)...   6,999
# 1   Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage) | 2....   8,999
# 2   Oppo A31 (Fantasy White, 6GB RAM, 128GB Storag...  12,490
# 3   Samsung Galaxy M11 (Black, 4GB RAM, 64GB Stora...  10,999
# 4   Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storag...  11,499
# 5   Redmi 9 (Carbon Black, 4GB RAM, 64GB Storage) ...   8,999
# 6   Redmi 9 Prime (Sunrise Flare, 4GB RAM, 64GB St...   9,999
# 7   Redmi Note 10 (Frost White, 4GB RAM, 64GB Stor...  12,999
# 8   Redmi 9A(Midnight Black 3GB RAM 32GB Storage) ...   7,799
# 9   Oppo A31 (Mystery Black, 6GB RAM, 128GB Storag...  12,490
# 10  Redmi Note 10 (Shadow Black, 4GB RAM, 64GB Sto...  12,999
# 11  Redmi 9A (Sea Blue 2GB RAM 32GB Storage) | 2GH...   6,999
# 12  Redmi 9A (Sea Blue 3GB RAM 32GB Storage)| 2GHz...   7,799
# 13  Samsung Galaxy M51 (Electric Blue, 6GB RAM, 12...  19,999
# ...
